# %%
# Stemming and Lemmatization using NLTK

import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('punkt_tab') # Added to resolve LookupError for 'punkt_tab'

text = "The children are playing games and the players are running quickly."

words = word_tokenize(text)

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print("Original Words:")
print(words)

print("\nStemming:")
for word in words:
    print(word, "->", stemmer.stem(word))

print("\nLemmatization:")
for word in words:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Original Words:
# ['The', 'children', 'are', 'playing', 'games', 'and', 'the', 'players', 'are', 'running', 'quickly', '.']
#
# Stemming:
# The -> the
# children -> children
# are -> are
# playing -> play
# games -> game
# and -> and
# the -> the
# players -> player
# are -> are
# running -> run
# quickly -> quickli
# . -> .
#
# Lemmatization:
# The -> The
# children -> child
# are -> are
# playing -> playing
# games -> game
# and -> and
# the -> the
# players -> player
# are -> are
# running -> running
# quickly -> quickly
# . -> .
